# %% [markdown]
# ### Multiple-Linear-Regression - Sckit Learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X, y = make_regression(n_samples=500, n_features=10, n_informative=5, noise=25.8, random_state=0)
print("X shape:", X.shape, "y shape:", y.shape)
# Out:
# X shape: (500, 10) y shape: (500,)

# %% [markdown]
# **Preprocess**

# %%
n_features = X.shape[1]

# %%
def preprocess(X):
    # Add dummy column of 1s in X as 0th column
    if X.shape[1] == n_features: 
        m = X.shape[0]
        ones = np.ones((m, 1))
        X = np.hstack((ones, X))
    return X

# %%
X = preprocess(X)
pd.DataFrame(X).head()
# Out:
#     0         1         2         3         4         5         6         7   \
# 0  1.0  1.706468  1.511639 -0.000417  0.374155  0.073285  0.701783  0.409552
# 1  1.0 -1.616956  0.640132 -0.369182 -0.239379 -0.738031 -0.024326  1.099660
# 2  1.0  0.093953 -0.130107  0.929505  0.582225 -2.739677  0.943046 -2.094603
# 3  1.0 -1.542758 -0.789954  0.537035 -0.286835 -2.369623 -0.767332  1.634406
# 4  1.0 -0.101003 -2.231538  0.436187  1.571463  1.324868 -0.587375  1.077315
#
#          8         9         10
# 0 -0.461894 -0.626490 -0.799593
# 1  0.279925 -0.098150  0.655264
# 2 -0.569312  0.269904  0.123722
# 3 -0.260560  0.128957  0.571227
# 4  0.840648  0.261106  0.811090

# %% [markdown]
# **Train test split**

# %%
XT, Xt, yT, yt = train_test_split(X, y, test_size=0.3, shuffle=False, random_state=0)

# %%
print("XT Shape:", XT.shape, "Xt Shape:", Xt.shape, "yT Shape:", yT.shape,"yt Shape:", yt.shape)
# Out:
# XT Shape: (350, 11) Xt Shape: (150, 11) yT Shape: (350,) yt Shape: (150,)

# %% [markdown]
# **Modelling**

# %%
model = LinearRegression()

# %% [markdown]
# **Train**

# %%
model.fit(XT, yT)
# Out:
# LinearRegression()

# %% [markdown]
# **Predict**

# %%
yp = model.predict(Xt)

# %% [markdown]
# **Evaluate**

# %%
r2 = model.score(Xt, yt)
print("R2 Score:", r2, "=", f"{round(r2*100, 2)}%")
# Out:
# R2 Score: 0.9321372696807688 = 93.21%

# %% [markdown]
# $\theta_0:$ Intercept
#
# $\theta_1 \theta_2 \theta_3 ... \theta_n:$ Coeficients

# %%
print("intercept:", model.intercept_)
print("Coeficients:", model.coef_)
# Out:
# intercept: -1.619202933669471
# Coeficients: [ 0.         -0.27031268 61.69074652 11.46052153 68.71743601 -0.47408626
#   1.01864169 41.4782553   0.53535847  0.77726017 22.75708008]
